# %% [markdown]
# # In Class Quiz
#
# Kevin J. Walchko, created 19 Nov 2017
#
# ---
#
# Ok, let's practice what we have learned up to this point with python, numpy, matplotlib, and sympy.
#
# **WARNING:** To be fare, you have had access to this quiz since day 1. Hopefully you did this entire thing ahead of time and have all of the solutions when you walked into class today. If not, good luck.
#
# ## Objectives
#
# - Apply what we have learned
#
# ## References
#
# - Previous lessons
#
# ## Setup

# %%
# %matplotlib inline

from __future__ import print_function
from __future__ import division
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Let's Play a Game
#
# Open up this or another Jupyter notebook and you have 5 minutes to answer your problem. When time expires, you **must** shut your notebook. When called upon, all you can do is run your solution, no more typing.
#
# You have to do this in a Jupyter notebook to get credit.

# %% [markdown]
# 1. You have the following 2 sensor data values you must plot. Also, ensure to label the axes, turn the grid on and set the title.
#   ```python
#   # this just gives you random sensor values
#   # obviously the numbers will change every time you run it
#   IR1 = np.random.uniform(0,10, size=[0,100])
#   IR2 = np.random.uniform(0,10, size=[0,100])
#   ```
# 1. Write a function that returns: 'high' if the arg is greater than 10, 'less' if the arg is less than 5, and 'good' if the arge is equal to or between 5 and 10. Do a for loop that goes from 0 to 15, and show the functions output vs the input: 1 less
# 1. Write a function that iterates through a string and prints each letter and its [ascii](http://www.asciitable.com/) decimal value on a new line like this: `a[97]`. Use `ord()` which will convert an ascii character to a decimal value. Feed your function the string "USAFA Falcons!" and show the output.
# 1. Create a 3x3 identity matrix I, a 3x3 matrix B where all of the values are 127 and a 3x3 matrix A where the values are:
#   $$
#   A = \begin{bmatrix}
#     1 & 2 & 3 \\
#     1 & 4 & 1 \\
#     3 & 2 & 1
#   \end{bmatrix}
#   $$
#   Then calculate the result: $1/64 \cdot I \cdot B \cdot (A + A)/I$.
#   You must show the code for this exact equation, do not simplify.
# 1. Create a function that prints one of 4 emojis based on the inputs: 'happy', 'sad', 'thrilled', 'scared'. Then write a program that iterates through each and prints the emoji, hit, use a for loop and an array. Have fun with this one.
# 1. Create a class for a Circle. You should be able to set it's `color` and `radius`. It should have 2 methods that return its `area()` and `circumference()`. Also, when printed, it should output:
#   ```python
#   Circle:
#      color: xxx
#      radius: xxx
#   ```
#   Create a Circle with radius 2 and show the methods returning the answer and print the circle.
# 1. Create the following equation: $\sin(\theta)\cos(\alpha)\sin(\theta) + \cos(\theta)^2\cos(\alpha) + \frac{\sin(\alpha)}{\cos(\alpha)}$. Then use python to simplify it and then substitute in $\theta$ is 45 deg and $\alpha$ is 20 deg.
# 1. Given the following code snipet:
#   ```python
#   def func(a):
#     ans = [0,1,2,3,4]
#     return ans[a]
#   func(7)
#   ```
#   As given, this will fail. Solve this 2 ways:
#   - Use try/expect to handle incorrect inputs
#   - Check the range before accessing the array
#   For each of the 2 ways, if `a` is out of range, return the first element of a.
# 1. Create a class for a Square. You should be able to set it's `color` and `dimension` (note, the dimensions are a tuple). It should have 2 methods that return its `area()` and `perimeter()`. Also, when printed, it should output:
#   ```python
#   Square:
#      color: xxx
#      dimensions: xxx
#   ```
#   Go ahead and create a Square 2 wide and 3 high. Show the methods returning the correct answers and print the square.
# 1. Create a 3x3 zeros matrix Z, a 3x3 matrix C where all of the values are 64 and a 3x3 matrix A where the values are:
#   $$
#   A = \begin{bmatrix}
#     1 & 2 & 3 \\
#     1 & 4 & 1 \\
#     3 & 2 & 1
#   \end{bmatrix}
#   $$
#   Then calculate the result: $1/64 \cdot (Z + A) \cdot B \cdot (A + A)$.
#   You must show the code for this exact equation, do not simplify.
# 1. You have the following 2 sensor data values you must plot. Also, ensure to label the axes, turn the grid on and set the title.
#   ```python
#   # this just gives you random sensor values
#   LeftEncoder = np.random.uniform(0,10, size=[0,100])
#   RightEncoder = np.random.uniform(0,10, size=[0,100])
#   ```
# 1. Given the following code snipet:
#   ```python
#   def func(a):
#     ans = {
#       'bob': 1,
#       'tom': 2,
#       'sally': 3
#     }
#     return ans[a]
#   func('john')
#   ```
#   As given, this will fail. Solve this 2 ways:
#   - Use try/expect to handle incorrect inputs
#   - Check the range before accessing the array
#   For each of the 2 ways, if `a` is out of range, return the `bob`.
# 1. Write a function that returns: 'high' if the arg is greater than 100, 'less' if the arg is less than 50, and 'good' if the arge is equal to or between 50 and 100. Do a for loop that goes from 0 to 150 in steps of 10, and show the functions output vs the input: 30 less
# 1. Create a function that prints one of 4 arrows based on the inputs: 'left', 'right', 'up', 'down'. Have fun with this one.
# 1. Write a function which given a string, will turn each letter into its ascii representation (use `ord()` for this) and then returns the sum of the letters. Only count upper and lower case a-z characters, you must ignore non-printing characters and spaces. Then use 'USAFA Falcons are the best!' for the test string. What is the sum?

# %% [markdown]
# # After Quiz (time permits): Lab 1
#
# Let's talk about Lab 1. Also, it might be useful to have paper or digital copies of the following documents during the lab. We all know how reliable the .EDU is.
#
# - Each Roomba creates its own WiFi access point and you will need to join the one your group is assigned to. [Read how to do that](https://marsuniversity.github.io/ece387/samba.pdf).
#   - Basically we will use secure shell (SSH) which establishes an encrypted connection between computers. This will allow us to run python commands on the robot.
#   - We will also use cryptographic keys to login to the Roomba's. This is far safer than username/password combinations (basically you are an idiot if you are authenticating using username/password).
# - During the lab, you will have to connect to the roomba's filing system like we do with the K drive. Read [Interfaceing Windoze and Linux file systems](file:///Users/kevin/github/ece387/website/www/samba.pdf) before the lab.
#   - We will be using [Samba](https://www.samba.org/) to allow Linux to talk the Windoze SMB/CIF protocol. Samba has become that standard for Linux/Unix/macOS to Windoze file integration.
#   - The other nice thing is, we can mount the roomba's file system and then edit python scripts directly in Windoze like it was a drive attached to your notebook.
#
# ## Shutting Down the Roomba
#
# The last class will shutdown the Roomba after the class. Our Roomba's have [archeyjs](https://www.npmjs.com/package/archeyjs)
# installed on them. Open a web browser to `10.10.10.1:8080` and you should see this, but with the name of your Roomba on it:
#
# <img src="pics/raspbian.png" width=50%>
#
# 1) Click on the `Commands` button on the webpage.
#
# <img src="pics/commands.png" width=50%>
#
# 2) Then select `sudo shutdown now`. Wait 1 minute and then unplug the RPi. The system will now be properly shutdown now.

# %% [markdown]
# -----------
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
